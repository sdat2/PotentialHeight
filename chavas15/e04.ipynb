# %% [markdown]
# # E04

# %%
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
from chavas15.e04.outerwind_r0input_MM0 import E04_outerwind_r0input_nondim_MM0
from matplotlib import pyplot as plt
from sithom.plot import plot_defaults

plot_defaults()

# %%
# Storm parameters
Vmax = 50  # [ms-1]
r0 = 900 * 1000  # [m]
fcor = 5e-5  # [s-1]

# Environmental parameters
# Outer region
Cdvary = False
Cd = 1.5e-3
w_cool = 2 / 1000  # [ms-1]

# Inner region
CkCdvary = False
CkCd = 1

# Eye adjustment
eye_adj = False
alpha_eye = 0.15

# %%
radii, aam = E04_outerwind_r0input_nondim_MM0(r0, fcor, True, Cd, w_cool)
# Out:
# 'E04_outerwind_r0input_nondim_MM0'  0.00234 s

# %%
plt.plot(radii, aam)
