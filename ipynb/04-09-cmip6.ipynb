# %%
import xarray as xr

# %%
import os

main_folder = "/mnt/lustre/a2fs-work1/work/n01/n01/sithom/adcirc-swan/tcpips"
data_folder = os.path.join(main_folder, "data", "cmip6")
file = "ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r9i1p1f1.nc"
file_path = os.path.join(data_folder, file)

# %%
xr.open_dataset(file_path)
# Out:
# /work/n01/n01/sithom/miniconda3/lib/python3.10/site-packages/xarray/backends/plugins.py:71: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# <xarray.Dataset>
# Dimensions:         (time: 1980, y: 384, x: 320, bnds: 2, vertex: 4)
# Coordinates:
#     lat             (y, x) float64 ...
#     lon             (y, x) float64 ...
#   * time            (time) object 1850-01-15 13:00:00 ... 2014-12-15 12:00:00
#     time_bounds     (time, bnds) object ...
#     lon_verticies   (y, x, vertex) float32 ...
#     lat_verticies   (y, x, vertex) float32 ...
#   * y               (y) int64 0 1 2 3 4 5 6 7 ... 377 378 379 380 381 382 383
#   * x               (x) int64 0 1 2 3 4 5 6 7 ... 313 314 315 316 317 318 319
#     lon_bounds      (bnds, y, x) float32 ...
#     lat_bounds      (bnds, y, x) float32 ...
#     member_id       object ...
#     dcpp_init_year  float64 ...
# Dimensions without coordinates: bnds, vertex
# Data variables:
#     tos             (time, y, x) float32 ...
# Attributes: (12/61)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      CMIP
#     branch_method:                    standard
#     branch_time_in_child:             674885.0
#     branch_time_in_parent:            295650.0
#     case_id:                          23
#     ...                               ...
#     intake_esm_attrs:variable_id:     tos
#     intake_esm_attrs:grid_label:      gn
#     intake_esm_attrs:zstore:          gs://cmip6/CMIP6/CMIP/NCAR/CESM2/histor...
#     intake_esm_attrs:version:         20190311
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           CMIP.NCAR.CESM2.historical.Omon.gn

# %%
ds = xr.open_dataset(file_path)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 1980, y: 384, x: 320, bnds: 2, vertex: 4)
# Coordinates:
#     lat             (y, x) float64 ...
#     lon             (y, x) float64 ...
#   * time            (time) object 1850-01-15 13:00:00 ... 2014-12-15 12:00:00
#     time_bounds     (time, bnds) object ...
#     lon_verticies   (y, x, vertex) float32 ...
#     lat_verticies   (y, x, vertex) float32 ...
#   * y               (y) int64 0 1 2 3 4 5 6 7 ... 377 378 379 380 381 382 383
#   * x               (x) int64 0 1 2 3 4 5 6 7 ... 313 314 315 316 317 318 319
#     lon_bounds      (bnds, y, x) float32 ...
#     lat_bounds      (bnds, y, x) float32 ...
#     member_id       object ...
#     dcpp_init_year  float64 ...
# Dimensions without coordinates: bnds, vertex
# Data variables:
#     tos             (time, y, x) float32 ...
# Attributes: (12/61)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      CMIP
#     branch_method:                    standard
#     branch_time_in_child:             674885.0
#     branch_time_in_parent:            295650.0
#     case_id:                          23
#     ...                               ...
#     intake_esm_attrs:variable_id:     tos
#     intake_esm_attrs:grid_label:      gn
#     intake_esm_attrs:zstore:          gs://cmip6/CMIP6/CMIP/NCAR/CESM2/histor...
#     intake_esm_attrs:version:         20190311
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           CMIP.NCAR.CESM2.historical.Omon.gn

# %%
ds["tos"].isel(time=0).plot()

# %%
ds["tos"].isel(x=150, y=150).plot()

# %%
from sithom.plot import plot_defaults

# %%
plot_defaults()

# %%
ds["tos"].isel(x=150, y=150).sel(time=ds.time.dt.month.isin([8])).plot()

# %%
import os

main_folder = "/mnt/lustre/a2fs-work1/work/n01/n01/sithom/adcirc-swan/tcpips"
data_folder = os.path.join(main_folder, "data", "cmip6")
file = "atmos_historical_CMIP.NCAR.CESM2.historical.Amon.gn_r1i1p1f1.nc"
file_path = os.path.join(data_folder, file)
atmos_ds = xr.open_dataset(file_path)

# %%
atmos_ds
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 1980, plev: 19, y: 192, x: 288, nbnd: 2)
# Coordinates:
#   * y               (y) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * x               (x) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * plev            (plev) float64 1e+05 9.25e+04 8.5e+04 ... 1e+03 500.0 100.0
#   * time            (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#     lon_bounds      (x, nbnd, y) float64 ...
#     lat_bounds      (y, nbnd, x) float64 ...
#     time_bounds     (time, nbnd) object ...
#   * nbnd            (nbnd) int64 0 1
#     lon             (x, y) float64 ...
#     lat             (x, y) float64 ...
#     member_id       object ...
#     dcpp_init_year  float64 ...
# Data variables:
#     hus             (time, plev, y, x) float32 ...
#     psl             (time, y, x) float32 ...
#     ta              (time, plev, y, x) float32 ...
# Attributes: (12/54)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      CMIP
#     branch_method:                    standard
#     branch_time_in_child:             674885.0
#     branch_time_in_parent:            219000.0
#     case_id:                          15
#     ...                               ...
#     intake_esm_attrs:member_id:       r1i1p1f1
#     intake_esm_attrs:table_id:        Amon
#     intake_esm_attrs:grid_label:      gn
#     intake_esm_attrs:version:         20190308
#     intake_esm_attrs:_data_format_:   zarr
#     intake_esm_dataset_key:           CMIP.NCAR.CESM2.historical.Amon.gn

# %%
atmos_ds["psl"].isel(x=150, y=150).sel(time=atmos_ds.time.dt.month.isin([8])).plot()

# %%
os.listdir(data_folder)
# Out:
# ['atmos_ssp585_ScenarioMIP.NCAR.CESM2.ssp585.Amon.gn_r4i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r5i1p1f1.nc',
#  'regrid_2d_0.2degree_atmos_regridded.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r6i1p1f1.nc',
#  'ocean_ssp585_ScenarioMIP.NCAR.CESM2.ssp585.Omon.gn_r10i1p1f1.nc',
#  'atmos_historical_CMIP.NCAR.CESM2.historical.Amon.gn_r1i1p1f1.nc',
#  'ocean_regridded.nc',
#  'atmos_historical_CESM2.historical.Amon.r10i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r1i1p1f1.nc',
#  'atmos_historical_CMIP.NCAR.CESM2.historical.Amon.gn_r5i1p1f1.nc',
#  'ocean_ssp585_ScenarioMIP.NCAR.CESM2.ssp585.Omon.gn.nc',
#  'ocean_ssp585_ScenarioMIP.NCAR.CESM2.ssp585.Omon.gn_r11i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r7i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r11i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r10i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r2i1p1f1.nc',
#  'regrid_2d_1degree_ocean_regridded.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r3i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r4i1p1f1.nc',
#  'atmos_historical_CMIP.NCAR.CESM2.historical.Amon.gn_r4i1p1f1.nc',
#  'regrid_2d_0.2degree_ocean_regridded.nc',
#  'ocean_ssp585_ScenarioMIP.NCAR.CESM2.ssp585.Omon.gn_r4i1p1f1.nc',
#  'atmos_ssp585_CESM2.ssp585.Amon.r10i1p1f1.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r9i1p1f1.nc',
#  'regrid_2d_ocean_regridded.nc',
#  'atmos.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn.nc',
#  'atmos_ssp585_ScenarioMIP.NCAR.CESM2.ssp585.Omon.gn.nc',
#  'regrid_2d_1degree_atmos_regridded.nc',
#  'atmos_historical_CMIP.NCAR.CESM2.historical.Amon.gn.nc',
#  'ocean_historical_CMIP.NCAR.CESM2.historical.Omon.gn_r8i1p1f1.nc']
