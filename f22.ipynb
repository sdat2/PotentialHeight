# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
from tcpips.constants import DATA_PATH, FIGURE_PATH

# %%
import xarray as xr
import datatree as dt

# %%
ds = xr.open_dataset(os.path.join(DATA_PATH, "mov.nc"))
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 673, xi: 161, yi: 161)
# Coordinates:
#     lon      (time, xi, yi) float64 ...
#     lat      (time, xi, yi) float64 ...
#   * time     (time) datetime64[ns] 2004-08-09 2004-08-09T00:15:00 ... 2004-08-16
# Dimensions without coordinates: xi, yi
# Data variables:
#     clon     (time) float64 ...
#     clat     (time) float64 ...
#     PSFC     (time, xi, yi) float32 ...
#     U10      (time, xi, yi) float32 ...
#     V10      (time, xi, yi) float32 ...
#     D        (time, xi, yi) float32 ...
#     U        (time, xi, yi) float32 ...
# Attributes:
#     description:  Tropical cyclone moving grid.

# %%
ds["lon"].isel(time=500).plot()

# %%
ds["lat"].isel(time=500).plot()

# %%
ds["U10"].isel(time=100).plot(x="lon", y="lat")
plt.scatter(ds["clon"].isel(time=100).values, ds["clat"].isel(time=100).values, marker="+")

# %%
ds["D"].isel(time=100).plot()

# %%
ds["U10"].isel(time=500).plot(x="lon", y="lat")

# %%
ds["V10"].isel(time=500).plot(x="lon", y="lat")

# %%
ds["PSFC"].isel(time=500).plot(x="lon", y="lat")

# %%
ds = xr.open_dataset(os.path.join(DATA_PATH, "sc.nc"))
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 673, yi: 385, xi: 393)
# Coordinates:
#     lon      (yi, xi) float64 ...
#     lat      (yi, xi) float64 ...
#   * time     (time) datetime64[ns] 2004-08-09 2004-08-09T00:15:00 ... 2004-08-16
# Dimensions without coordinates: yi, xi
# Data variables:
#     clon     (time) float64 ...
#     clat     (time) float64 ...
#     PSFC     (time, yi, xi) float32 ...
#     U10      (time, yi, xi) float32 ...
#     V10      (time, yi, xi) float32 ...
# Attributes:
#     description:  Tropical cyclone static grid.

# %%
ds.lon.plot()

# %%
ds.lat.plot()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 673, xi: 385, yi: 393)
# Coordinates:
#     lon      (time, xi, yi) float64 ...
#     lat      (time, xi, yi) float64 ...
#   * time     (time) datetime64[ns] 2004-08-09 2004-08-09T00:15:00 ... 2004-08-16
# Dimensions without coordinates: xi, yi
# Data variables:
#     clon     (time) float64 ...
#     clat     (time) float64 ...
#     PSFC     (time, xi, yi) float32 ...
#     U10      (time, xi, yi) float32 ...
#     V10      (time, xi, yi) float32 ...
# Attributes:
#     description:  Tropical cyclone moving grid.

# %%
ds.U10.isel(time=0).plot(x="lon", y="lat")

# %%
ds.V10.isel(time=150).plot(x="lon", y="lat")

# %%
ds.PSFC.isel(time=150).plot(x="lon", y="lat")
